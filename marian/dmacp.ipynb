# %% [markdown]
# # DMACP data processing

# %% [markdown]
# Load zipped data file and unpack:

# %%
import os.path

data_path = "../dmacp_data"

# %% [markdown]
# ## Merge content files

# %%
import json
import re

content_list_filepath = data_path+'/article_list.json'

projects_data_filepath = data_path+'/article_list.json'

merged_content_data = {
    'contribution': {
        'filepath': data_path+'/contributions.json',
        'data': {}
    },
    'field_note': {
        'filepath': data_path+'/field_notes.json',
        'data': {}
    },
    'project': {
        'filepath': data_path+'/projects.json',
        'data': {}
    }
}

# Helper functions

def get_text_from_html(raw_html):
    
    # from https://stackoverflow.com/a/12982689
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    
    cleantext = cleantext.replace('&nbsp;', ' ')
    cleantext = cleantext.replace('\n\n', ' ')
    cleantext = cleantext.replace('\r\n', ' ')
    cleantext = cleantext.replace('\n', ' ')    
    cleantext = cleantext.strip()
    
    return cleantext

def get_embed_content_entry(entry_data):
    if entry_data['title'] or entry_data['caption']:
        return {
            'type': entry_data['acf_fc_layout'],
            'title': entry_data['title'],
            'text': entry_data['caption'],
        }
    
    return {}

def get_text_content_entry(entry_data):
    text = get_text_from_html(entry_data['text'])
    
    if text:
        return {
            'type': entry_data['acf_fc_layout'],
            'text': text,
        }

    return {}

def get_image_content_entry(entry_data):    
    text_elements = []
    for image_data in entry_data['image']:
        if image_data['caption']:
            text_elements.append(image_data['caption'].strip())
        if image_data['description']:
            text_elements.append(image_data['description'].strip())
    
    text = ' '.join(text_elements)
    
    if text:
        return {
            'type': entry_data['acf_fc_layout'],
            'text': get_text_from_html(text)
        }
    
    return {}
    

def get_essentialize_contribution_data(raw_data):
    return get_essentialize_project_data(raw_data)

def get_essentialize_field_note_data(raw_data):
    data = {}
    
    data['link'] = 'https://notes.anthropocene-curriculum.org/id/%s' % raw_data['id']
    
    data['text'] = get_text_from_html(raw_data['acf']['text'])
    
    return data

def get_essentialize_project_data(raw_data):
    data = {}
    
    # title
    data['title'] = raw_data['title']['rendered']
    
    # subtitle
    data['subtitle'] = raw_data['acf']['subtitle']
    
    # abstract
    data['abstract'] = get_text_from_html(raw_data['acf']['abstract'])
    
    # link
    data['link'] = raw_data['link'].replace('content.', 'www.')
        
    # content
    data['content'] = []
    if raw_data['acf']['_content']['content']:
        for entry in raw_data['acf']['_content']['content']:
            
            ignored_types = ['iframe', 'featured', 'featured-children', 'reading-list', 'pdf']
        
            # Get content based on layout type
            content = {}
            if entry['acf_fc_layout'] == 'embed':
                content = get_embed_content_entry(entry)
            elif entry['acf_fc_layout'] == 'text':
                content = get_text_content_entry(entry)
            elif entry['acf_fc_layout'] == 'image':
                content = get_image_content_entry(entry)
                
            elif entry['acf_fc_layout'] in ignored_types:
                # doesn't hold any content. skipped for now
                continue

            else:
                print('Warning: Unhandled content type %s.' % entry['acf_fc_layout'])
            
            # Add content if not empty
            if content:
                data['content'].append(content)

    return data

# Merge content files

with open(content_list_filepath) as content_list_file:
    data = json.load(content_list_file)
    
    for entry in data:
        filepath = 'dmacp_data/%s/%s.json' % (entry['type'], entry['slug'])
        
        with open(filepath) as json_file:
            json_data = json.load(json_file)
        
            essentialized_data = {}
            if entry['type'] == 'contribution':
                essentialized_data = get_essentialize_contribution_data(json_data[0])
            elif entry['type'] == 'field_note':
                essentialized_data = get_essentialize_field_note_data(json_data[0])
            elif entry['type'] == 'project':
                essentialized_data = get_essentialize_project_data(json_data[0])
        
            merged_content_data[entry['type']]['data'][entry['slug']] = essentialized_data

for category in merged_content_data:
    filepath = merged_content_data[category]['filepath']
    data = merged_content_data[category]['data']
    
    with open(filepath, 'w') as outfile:
        json.dump(data, outfile, sort_keys=True, indent=4)

num_contributions = len(merged_content_data['contribution']['data'])
num_field_notes = len(merged_content_data['field_note']['data'])
num_projects = len(merged_content_data['project']['data'])
print('Merged %d contributions, %d field_notes, and %d projects.' % (num_contributions, num_field_notes, num_projects))
# Out:
# Merged 264 contributions, 288 field_notes, and 103 projects.

# %% [markdown]
# ## Run text analysis

# %%
# pip install spacy
# python -m spacy download en_core_web_sm

import json
import spacy

# Load English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load("en_core_web_sm")

# compressed content files
contributions_file = data_path+'/contributions.json'
field_notes_file = data_path+'/field_notes.json'
projects_file = data_path+'/projects.json'

# Some helper functions

def get_merged_contribution_text(contribution_data):
    texts = [contribution_data['abstract']]
    for entry in contribution_data['content']:
        texts.append(entry['text'])
    return ' '.join(texts)

def get_merged_field_note_text(field_note_data):
    return field_note_data['text']

def get_merged_project_text(project_data):
    texts = [project_data['abstract']]
    for entry in project_data['content']:
        texts.append(entry['text'])
    return ' '.join(texts)

# --- Your code here: ---


# Some field note example code …     
with open(field_notes_file) as f:
    field_notes = json.load(f)
    
    field_note = field_notes['1566946414604-johnwkim']
    
    print(field_note['link'])

    text = get_merged_field_note_text(field_note)
    doc = nlp(text)
    
    # Find named entities, phrases and concepts
    for entity in doc.ents:
        print(entity.text, entity.label_)
        

# Some project example code …
with open(projects_file) as f:
    projects = json.load(f)
    
    project = projects['essay-series']
    
    print(project['title'])
    print(project['link'])

    text = get_merged_project_text(project)
    doc = nlp(text)
    
    # Find named entities, phrases and concepts
    for entity in doc.ents:
        print(entity.text, entity.label_)
        

# Some contribution example code …

with open(contributions_file) as f:
    contributions = json.load(f)
    
    contribution = contributions['navigating-the-anthropocene-river']
    
    print(contribution['title'])
    print(contribution['link'])

    text = get_merged_contribution_text(contribution)
    doc = nlp(text)
    
    # Find named entities, phrases and concepts
    for entity in doc.ents:
        print(entity.text, entity.label_)
# Out:
# https://notes.anthropocene-curriculum.org/id/5650
# Frank Bibeau PERSON
# Ojibwe PERSON
# Manoomin PERSON
# 2018 DATE
# White Earth LOC
# Ojibwe GPE
# Anishinaabe LOC
# White Earth LOC
# 1855 DATE
# Treaty Authority ORG
# Manoomin PERSON
# Chippewa ORG
# After the Industrial River: Essay Collection
# https://www.anthropocene-curriculum.org/project/mississippi/field-stations/field-station-1-sediment-settlement-sentiment/essay-series/
# the Mississippi River LOC
# three CARDINAL
# Field Station 1’s ORG
# Morgan Adamson ORG
# Bruce Braun PERSON
# Roopali Phadke PERSON
# St. Anthony Falls PERSON
# 1863 DATE
# Benjamin Franklin Upton PERSON
# the Twin Cities ORG
# the Upper Mississippi ORG
# the twenty-first century DATE
# the Twin Cities ORG
# the Upper St. Anthony Falls Lock ORG
# 2015 DATE
# the National Park Service ORG
# NPS ORG
# reposition the Lock WORK_OF_ART
# the Central Riverfront LOC
# Friends of the Lock &amp ORG
# Dam ORG
# The Falls Initiative WORK_OF_ART
# Falls PERSON
# October 22, 2019 DATE
# the US Army Corps of Engineers ORG
# the Upper St. Anthony Falls Lock ORG
# the Upper Harbor Terminal ORG
# UHT ORG
# the Mississippi River LOC
# UHT ORG
# the Mississippi River LOC
# the Army Corps ORG
# 2017 DATE
# the Upper St. Anthony Lock ORG
# St. Anthony Lock PRODUCT
# Dam FAC
# Minneapolis GPE
# Lock PERSON
# 1 CARDINAL
# the Ford Parkway Bridge FAC
# Minneapolis GPE
# Mississippi GPE
# Mississippi LOC
# Anthropocene River LOC
# Congress ORG
# first ORDINAL
# the Army Corps of Engineers ORG
# six dams QUANTITY
# between 1880 and 1907 DATE
# 1910 DATE
# Corps GPE
# America GPE
# first ORDINAL
# Lock FAC
# St. Paul GPE
# Today DATE
# Corps ORG
# twenty-nine CARDINAL
# the Upper Mississippi River LOC
# Minneapolis GPE
# St. Louis GPE
# Dam ORG
# first ORDINAL
# the Twin Cities ORG
# the 1850s DATE
# fifty years DATE
# Dakota GPE
# the Upper Mississippi FAC
# Mississippi GPE
# Minnesota GPE
# Dakota GPE
# Dakota GPE
# the Dakota War EVENT
# 1862 DATE
# Pig’s ORG
# Wakan Tipi PERSON
# Dakota ORG
# one CARDINAL
# Mississippi GPE
# African American NORP
# the Civil War EVENT
# Dred Scott PERSON
# Minnesota GPE
# the twentieth century DATE
# Minneapolis GPE
# African American NORP
# North Minneapolis GPE
# Today DATE
# the Upper Harbor Terminal ORG
# Upper Mississippi FAC
# today DATE
# the Upper Harbor Terminal FAC
# Lock PERSON
# Mississippi LOC
# Anthropocene River LOC
# the Upper Harbor Terminal ORG
# Anthropocene PRODUCT
# Bruce Vento PERSON
# today DATE
# mid-nineteenth-century DATE
# Navigating the Anthropocene River
# https://www.anthropocene-curriculum.org/contribution/navigating-the-anthropocene-river/
# September 2019 DATE
# the Mississippi River’s LOC
# Lake Itasca LOC
# hundred-day DATE
# Anthropocene River Journey LOC
# twenty-five CARDINAL
# River Semester of Augsburg University ORG
# Minneapolis GPE
# Minnesota GPE
# Joe Underhill PERSON
# the River Semester FAC
# Augsburg University ORG
# Anthropocene PRODUCT
# Anthropocene LOC
# the Lower Mississippi LOC
# Joe PERSON
# Anthropocene WORK_OF_ART
# the River Semester FAC
# hundred-day DATE
# the Mississippi River LOC
# 2015 DATE
# 2018 DATE
# 2021 DATE
# Haus NORP
# Welt PERSON
# Max Planck Institute for the History of Science ORG
# Fall 2019 DATE
# Anthropocene River Journey LOC
# Anthropocene LOC
# our day DATE
# Anthropocene FAC
# Capitalocene GPE
# the Great Acceleration ORG
# the Sixth Extinction EVENT
# Alya Ansari PERSON
# Anthropocene River LOC
# Anthropocene GPE
# Anthropocene LOC
# Anthropocene PRODUCT
# the Mississippi River LOC
# American NORP
# Joseph Underhill PERSON
# What We Learned from the River WORK_OF_ART
# Open Rivers PERSON
# 6 CARDINAL
# hundreds of miles QUANTITY
# 2019 DATE
# Anthropocene River LOC
# 500 CARDINAL
# the Mississippi River LOC
# Anthropocene LOC
# Timothy Morton PERSON
# The Ecological Thought WORK_OF_ART
# Cambridge GPE
# MA GPE
# Harvard University Press ORG
# 2010 DATE
# Matt Edgeworth PERSON
# Jeffrey Benjamin PERSON
# What Is a River? WORK_OF_ART
# The Chicago River LOC
# Rivers of the PERSON
# Anthropocene GPE
# ed PERSON
# Jason M. Kelley PERSON
# Berkeley: University of California Press ORG
# 162–75 CARDINAL
# Anthropocene River LOC
# one CARDINAL
# 2019 DATE
# One CARDINAL
# Anthropocene LOC
# Anthropocene LOC
# Minneapolis GPE
# one CARDINAL
# Field Note ORG
# Joe PERSON
# one CARDINAL
# From 2016 to 2017 DATE
# the previous year DATE
# 36 percent PERCENT
# 2017 DATE
# more than 17 million CARDINAL
# American NORP
# three million CARDINAL
# 17 CARDINAL
# Forty million CARDINAL
# nearly 20 percent PERCENT
# Americans NORP
# 33 percent PERCENT
# between 1999 DATE
# 2017.The NORP
# the American Psychiatric Association ORG
# Lee Siegel PERSON
# America GPE
# Depressed GPE
# New York Times ORG
# Jan 2, 2020 DATE
# the years ahead DATE
# daily DATE
# Anthropocene LOC
# Donna Haraway PERSON
# Anthropocene, Capitalocene, Plantationocene WORK_OF_ART
# Kin PERSON
# 6 CARDINAL
# 2015 DATE
# 159–65 CARDINAL
# Anna Tsing PERSON
# The Mushroom at the End of the World: On the Possibilities of Life in the Capitalist Ruins. WORK_OF_ART
# Princeton University Press ORG
# 2017 CARDINAL
# Robin Wall Kimmerer PERSON
# the Teachings of Plants PERSON
# Minneapolis GPE
# Milkweed PERSON
# Anthropocene LOC
# our day DATE
# daily DATE
# One CARDINAL
# two CARDINAL
# Ojibwe GPE
# Christian NORP
# the Mississippi River LOC
# Emily Knudson PERSON
# the Mississippi River LOC
# Lake Itasca FAC
# Joe Underhill PERSON
# Anna Tsing PERSON
# The Mushroom at the End of the World WORK_OF_ART
# Greeks PERSON
# don PERSON
# anomie PERSON
# Anthropocene PRODUCT
# Buturian Larson PERSON
# Petrochemical Corridor PERSON
# Baton Rouge GPE
# New Orleans GPE
# the Gulf of Mexico LOC
# Neli Wagner PERSON
# roughly one hundred days DATE
# Mississippi River LOC
# Minnesota GPE
# the Gulf of Mexico LOC
# Anthropocene LOC
# Anthropocene LOC
# Mississippi LOC
# Anthropocene LOC
# engulf us PERSON
# the Anthropocene Curriculum FAC
# Shanai Matteson PERSON
# Graci Horne PERSON
# the Upper Mississippi FAC
# Horne PERSON
# Lakota ORG
# four CARDINAL
# Turtle Island LOC
# the North American Continent ORG
# Horne PERSON
# Graci Horne PERSON
# Shanai Matteson PERSON
# Wilderness Inquiry ORG
# Minneapolis GPE
# Field Note ORG
# John Kim PERSON
# Mississippi GPE
# Dakota GPE
# Makoce GPE
# Mni PERSON
# Lake Itasca FAC
# Coffee Pot Landing FAC
# Gaagigeyaashiik PERSON
# Dawn Goodwin PERSON
# first ORDINAL
# A month later DATE
# St. Louis GPE
# Saundi Kloeckener PERSON
# the Native Women’s Care Circle FAC
# Sunday DATE
# morning TIME
# Gaagigeyaashiik PERSON
# Dawn Goodwin PERSON
# Everlasting Wind PERSON
# Field Note ORG
# Anthony Tran Students PERSON
# Naomi Klein PERSON
# This Changes Everything WORK_OF_ART
# Field Note ORG
# Upper Mississippi LOC
# the Twin Cities ORG
# St. Louis GPE
# the Mississippi River LOC
# the River Semester ORG
# Anthropocene GPE
# two CARDINAL
# Anthropocene LOC
# Anthropocene LOC
# Anthropocene LOC
# La Crosse GPE
# Wisconsin GPE
# Anthropocene GPE
# the US Army Corps of Engineers ORG
# the Upper Mississippi River LOC
# Field Note ORG
# Peter Haff PERSON
# the US Army Corps of Engineers ORG
# Mississippi LOC
# nine-foot QUANTITY
# the Upper Mississippi LOC
# St. Louis Field Note FAC
# Temporary GPE
# Missouri GPE
# St. Louis GPE
# Louisiana GPE
# Baton Rouge GPE
# New Orleans GPE
# Sauget GPE
# Illinois GPE
# Monsanto Town PRODUCT
# St. Louis GPE
# day DATE
# Weldon Springs FAC
# years DATE
# Cahokia GPE
# New Town GPE
# St. Charles GPE
# Missouri GPE
# Missouri River LOC
# St. Louis GPE
# Ferguson GPE
# Andrew Gustin PERSON
# “Island 7” WORK_OF_ART
# Kentucky Bend GPE
# Field Note ORG
# Tom Turnbull PERSON
# the Chemical Corridor FAC
# Louisiana GPE
# Field Note ORG
# John Kim PERSON
# the Star Wars Landspeeder WORK_OF_ART
# Baton Rouge GPE
# New Orleans GPE
# the Lower Mississippi LOC
# Anthropocene PRODUCT
# New Orleans GPE
# Baton Rouge GPE
# Louisiana GPE
# Field Note ORG
# Simon Turner PERSON
# Simon Turner PERSON
# one CARDINAL
# Mississippi Delta LOC
# Amalia Lequizamón PERSON
# Louisiana State University ORG
# LSU ORG
# the Center for River Studies’ ORG
# Mississippi River LOC
# the Lower Mississippi LOC
# the Bonnet Carré Spillway FAC
# Field Note ORG
# Joe PERSON
# New Orleans GPE
# the Old River Control Structure ORG
# St. Louis GPE
# the Gulf of Mexico LOC
# Mississippi LOC
# the City of New Orleans GPE
# Steven Diehl PERSON
# Angola Museum ORG
# the Louisiana State Penitentiary FAC
# John Kim PERSON
# Angola Museum ORG
# the Louisiana State Penitentiary ORG
# Angola GPE
# Angola GPE
# African American NORP
# Roman NORP
# Field Note ORG
# Joe Underhill PERSON
# Baton Rouge GPE
# New Orleans GPE
# ExxonMobil ORG
# first ORDINAL
# German NORP
# American NORP
# the Baton Rouge Refinery ORG
# the Anthropocene River LOC
# Field Note ORG
# Anthropocene GPE
# the Mississippi River LOC
# the Max Planck Institute for Chemistry ORG
# Germany GPE
# the Chemical Corridor LOC
# New Orleans GPE
# Baton Rouge GPE
# Isle de Jean LOC
# Charles GPE
# Louisiana GPE
# Joe PERSON
# the Gulf of Mexico LOC
# The Louisiana Delta LOC
# about five inches QUANTITY
# the twentieth century DATE
# 2050 DATE
# ten CARDINAL
# New Orleans GPE
# Lower Ninth Ward LOC
# 2050 DATE
# hundreds of millions MONEY
# New Orleans GPE
# the Gulf Coast LOC
# Louisiana GPE
# Karl Marx PERSON
# Benjamin Steininger PERSON
# Anthropocene FAC
# Indigenous Peoples ORG
# Anthropocene LOC
# Theodor Adorno GPE
# Anthropocene GPE
# today DATE
# Anthropocene LOC
# Anthropocene LOC
# the Mississippi River LOC
# La Crosse GPE
# Wisconsin GPE
# Field Note ORG
# Anthropocene GPE
# Western NORP
# One CARDINAL
# Anthropocene LOC
# Anthropocene LOC
# Anthropocene LOC
# Anthropocene PRODUCT
# American NORP
# two CARDINAL
# night TIME
# daily DATE
# modern life WORK_OF_ART
# the Global South LOC
# Rob Nixon PERSON
# Slow Violence ORG
# Cambridge GPE
# MA GPE
# Harvard University Press ORG
# Earth LOC
# Donna Haraway PERSON
# Chthulucene WORK_OF_ART
# Anthropocene LOC
# Anthropocene LOC
# flowSee GPE
# Mihaly Csikszentmihalyi PERSON
# New York GPE
# 2008 DATE
# Aristotelian NORP
# Canoe PERSON
# Anthropocene LOC
# Anthropocene LOC
# Wolf Island GPE
# Missouri GPE
# October 14, 2019 DATE
# Joe Underhill PERSON
# Wolf Island GPE
# Mississippi LOC
# Ohio GPE
# Cairo GPE
# Illinois GPE
# New Madrid GPE
# Missouri GPE
# last-minute TIME
# sandy beach PERSON
# Carlina PERSON
# moon PERSON
# Audrey PERSON
# Joe PERSON
# Mississippi GPE
# tens of millions MONEY
# river angels WORK_OF_ART
# Chi-Nations Youth Council ORG
# Chicago GPE
# Temporary GPE
# Chi-Nations Youth Council ORG
# Chicago GPE
# 1817 DATE
# Louisiana GPE
# Badger Army Ammunition Plant ORG
# Illinois GPE
# St. Louis GPE
# the “Asian Carp Convivial EVENT
# the Mississippi River LOC
# China GPE
# US GPE
# Cooperation Jackson PERSON
# Jackson GPE
# Mississippi GPE
# Republican NORP
# Poche Park FAC
# Pauline GPE
# Louisiana GPE
# Baton Rouge GPE
# New Orleans GPE
# Scott PERSON
# 1817 DATE
# New Orleans GPE
# Louisiana GPE
# Joe Underhill PERSON
# the Anthropocene River LOC
# a long day DATE
# the Chemical Corridor FAC
# Louisiana GPE
# Joe PERSON
# Saundi Kloeckener PERSON
# Sunday DATE
# mornings TIME
# the Gulf of Mexico LOC
# New Orleans GPE
# Ben PERSON
# New Orleans GPE
# Mississippi GPE
# Anthropocene LOC
# the French Quarter of New Orleans EVENT
# Joe Underhill PERSON
# the Gulf of Mexico LOC
# Anthropocene LOC
# gulf LOC
# hundreds CARDINAL
# Audrey Buturian-Larson PERSON
# Steven Diehl PERSON
# Nell Gehrke PERSON
# Fiona ORG
# Nick Houde PERSON
# Jaclyn Arndt PERSON
# Emily Knudson PERSON
