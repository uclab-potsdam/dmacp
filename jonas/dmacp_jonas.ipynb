# %% [markdown]
# # DMACP data processing

# %% [markdown]
# ## Scraping

# %% [markdown]
# Download content files from anthropocene website:

# %%
from lib.anthropocene.Scraper import Scraper

anthropocene_scraper = Scraper('../dmacp_data')
anthropocene_scraper.scrape_content()

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Reduce content files and merge them into one json file for each type (contribution, project, field note):

# %%
import json
import os
from lib.anthropocene.Preprocessor import Preprocessor

# ---

source_dir = '../dmacp_data'
output_dir = './data/preprocess/reduced'

merged_data_filenames = {
    'contribution': 'contributions.json',
    'field_note': 'field_notes.json',
    'project': 'projects.json',
}

# ---

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# ---

anthropocene_preprocessor = Preprocessor(source_dir)
merged_contents = anthropocene_preprocessor.get_merged_article_contents_by_type()

for (type, data) in merged_contents.items():
    filepath = '%s/%s' % (output_dir, merged_data_filenames[type])

    with open(filepath, 'w') as outfile:
        json.dump(data, outfile, sort_keys=True, indent=4)

# %% [markdown]
# Create json file containing all contents:

# %%
import json
import os
from pathlib import Path

# ---

source_dir = '../dmacp_data'
output_file = './data/preprocess/merged/fully_merged_contents.json'

# ---

output_dir = path = Path(output_file).parent
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# ---

anthropocene_preprocessor = Preprocessor(source_dir)
fully_merged_content = anthropocene_preprocessor.get_fully_merged_article_contents()

with open(output_file, 'w') as outfile:
    json.dump(fully_merged_content, outfile, sort_keys=True, indent=4)

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Article Similarities

# %% [markdown]
# Compare all articles with all following articles.
# (Because the similarity operation is commutative you can skip the reversed comparison to save some time.)

# %%
import json
import os
import shutil
from lib.anthropocene.Analyzer import Analyzer

# ---

source_filepath = './data/preprocess/merged/fully_merged_contents.json'
output_dir = './data/analysis/article_similarities/raw'

# ---

if os.path.exists(output_dir):
    shutil.rmtree(output_dir)
os.makedirs(output_dir)

# ---

with open(source_filepath) as json_file:
    contents = json.load(json_file)

    anthropocene_analyzer = Analyzer()
    
    processed_article_ids = []
    for article_id in contents:
        unprocessed_contents = dict([(key, val) for key, val in contents.items() if key not in processed_article_ids])

        similarities = anthropocene_analyzer.get_article_similarities(article_id, unprocessed_contents)
        sorted_similarities = dict(sorted(similarities.items(), key=lambda item: item[1], reverse=True))

        filepath = '%s/%s.json' % (output_dir, article_id)
        with open(filepath, 'w') as outfile:
            json.dump(sorted_similarities, outfile, sort_keys=False, indent=4)

        processed_article_ids.append(article_id)
# Out:
# 12646 <-> 12724
# 12646 <-> 12854
# 12646 <-> 12856
# 12646 <-> 13164
# 12646 <-> 13167
# 12646 <-> 13170
# 12646 <-> 13177
# 12646 <-> 13180
# 12646 <-> 13183
# 12646 <-> 13364
# 12646 <-> 13368
# 12646 <-> 13371
# 12646 <-> 14258
# 12646 <-> 1566669833833-underhil
# 12646 <-> 1566670143264-underhil
# 12646 <-> 1566855154819-underhil
# 12646 <-> 1566877164374-johnwkim
# 12646 <-> 1566877523518-johnwkim
# 12646 <-> 1566877596229-johnwkim
# 12646 <-> 1566920087935-underhil
# 12646 <-> 1566922144169-johnwkim
# 12646 <-> 1566946414604-johnwkim
# 12646 <-> 1567000427783-underhil
# 12646 <-> 1567005100424-temporarycontinent
# 12646 <-> 1567008776790-johnwkim
# 12646 <-> seminar-film-un-bounded-engineering-and-evolutionary-stability
# 12646 <-> seminar-filtering-the-anthropocene
# 12646 <-> seminar-governing-the-technosphere
# 12646 <-> seminar-imaging-the-anthropocene
# 12646 <-> seminar-modelling-wicked-problems
# 12646 <-> seminar-reflection-2
# 12646 <-> seminar-reflections-algorithmic-intermediation-and-smartness
# 12646 <-> seminar-report-anthropogenic-landscapes
# 12646 <-> seminar-report-filtering-the-anthropocene
# 12646 <-> seminar-report-geo-politics
# 12646 <-> seminar-report-slow-media
# 12646 <-> seminar-risk-equity
# 12646 <-> seminar-romancing-the-anthropocene
# 12646 <-> seminar-sensing
# 12646 <-> seminar-sensing-the-insensible
# 12646 <-> seminar-slow-media
# 12646 <-> seminar-techno-metabolism
# 12646 <-> seminar-un-bounded-engineering-and-evolutionary-stability
# 12646 <-> seminar-valuing-nature
# 12646 <-> sever-pre-emptive-strategy-for-an-open-arctic
# 12646 <-> shadowing-the-anthropocene
# 12646 <-> shaped-by-rivers
# 12646 <-> sharing-surveillance-data
# 12646 <-> significant-and-insignificant-mounds
# 12646 <-> significant-and-insignificant-mounds-2
# 12646 <-> slow-disaster
# 12646 <-> social-witnessing
# 12646 <-> somewhere-somehow-a-co-evolution-story
# 12646 <-> sounding-landscapes
# 12646 <-> specifics-of-vulnerability
# 12646 <-> st-louis-anthropocene-field-campus
# 12646 <-> state-of-nature-in-india
# 12646 <-> state-of-nature-some-philosophical-issues
# 12646 <-> stranging-the-anthropocene-refraction
# 12646 <-> systems-analysis-and-modeling
# 12646 <-> t-rain-lines
# 12646 <-> tactics-for-quotidian-anthropocenes
# 12646 <-> tactics-for-quotidian-anthropocenes-2
# 12646 <-> taking-nature-into-account-historical-perspectives-and-paradoxes
# 12646 <-> technosphere-co-evolution-a-seminal-seminar-conversation
# 12646 <-> technosphere-magazine
# 12646 <-> technostratigraphy-of-a-technological-object
# 12646 <-> telling-time-through-lagoons-of-human-waste-at-the-western-treatment-plant
# 12646 <-> temporary-continent
# 12646 <-> terraforming
# 12646 <-> test-contribution
# 12646 <-> the-abolition-of-market-dependency
# 12646 <-> the-aerocene-campus
# 12646 <-> the-american-bottom
# 12646 <-> the-anthropocene-and-our-post-natural-future-2
# 12646 <-> the-anthropocene-in-light-of-biological-feedback
# 12646 <-> the-anthropogenic-influence-onto-the-air-quality-along-the-mississippi-river-findings
# 12646 <-> the-confluence-area
# 12646 <-> the-current-mississippi-an-anthropocene-river
# 12646 <-> the-danish-text
# 12646 <-> the-fight-for-alaskas-arctic-has-just-begun
# 12646 <-> the-floating-ear
# 12646 <-> the-four-dimensional-mississippi
# 12646 <-> the-free-sea
# 12646 <-> the-free-sea-2
# 12646 <-> the-great-green-desert
# 12646 <-> the-hedge
# 12646 <-> the-hyphen
# 12646 <-> the-lena-is-worthy-of-baikal-defining-remoteness-across-the-north-and-the-east
# 12646 <-> the-lichtenberg-case
# 12646 <-> the-lichtenberg-case-2
# 12646 <-> the-maledives-case
# 12646 <-> the-mississippi-basin-an-operational-landscape
# 12646 <-> the-politics-of-modeling
# 12724 <-> a-curriculum-for-the-anthropocene
# 12724 <-> a-legacy-of-the-technosphere
# 12724 <-> a-n-t-h-r-o-p-o-z-i-n-e-0
# 12724 <-> a-recipe-for-crafting-color-the-revival-of-natural-dyeing-in-south-india
# 12724 <-> a-river-indicts
# 12724 <-> a-river-semester
# 12724 <-> a-seed-a-sound
# 12724 <-> a-slobjects-exercise-whats-in-our-pockets
# 12724 <-> a-suspended-archive
# 12724 <-> a-trace-a-breath
# 12724 <-> ac-event-2016
# 12724 <-> acknowledging-indigenous-land-and-a-performance-of-idle-no-more-bonus-episode
# 12724 <-> acquiring-and-optimizing-sustainable-relationships-for-good-solid-cash-flow-streams-or-speaking-with-plants
# 12724 <-> adaptive-modeling
# 12724 <-> after-extraction-a-partical-political-ecology-of-central-illinois
# 12724 <-> agricultural-revolution-vs-the-industrial-revolution
# 12724 <-> alternatives-to-global-challenges
# 12724 <-> ambient-infrastructures-generator-life-in-nigeria
# 12724 <-> amongst-relatives
# 12724 <-> an-anthropocene-challenge-creating-models-for-landscape-scale-change
# 12724 <-> an-anthropocene-in-two-parts
# 12724 <-> anthropocene-archeology-of-the-present
# 12724 <-> anthropocene-campus-melbourne
# 12724 <-> anthropocene-campus-melbourne-2018-a-report
# 12724 <-> anthropocene-campus-philadelphia
# 12724 <-> anthropocene-campus-venice-2021
# 12724 <-> anthropocene-east-asia
# 12724 <-> anthropocene-india
# 12724 <-> anthropocene-lecture-john-mcneill
# 12724 <-> anthropocene-lecture-julia-adeney-thomas
# 12724 <-> anthropocene-lecture-karen-litfin
# 12724 <-> anthropocene-lecture-philippe-descola
# 12724 <-> anthropocene-lecture-prasannan-parthasarathi
# 12724 <-> anthropocene-lecture-sheila-jasanoff
# 12724 <-> anthropocene-reinsurance-corporation-anthrore
# 12724 <-> anthropocene-river-campus-opening-plenary
# 12724 <-> anthropocene-river-campus-plenary-i
# 12724 <-> anthropocene-river-campus-seminar-clashing-temporalities
# 12724 <-> anthropocene-river-campus-seminar-commodity-flows
# 12724 <-> anthropocene-river-campus-seminar-exhaustion-and-imagination
# 12724 <-> anthropocene-river-campus-seminar-un-bounded-engineering-and-evolutionary-stability
# 12724 <-> anthropocene-river-campus-the-human-delta
# 12724 <-> anthropocene-river-campus-the-human-delta-short-film
# 12724 <-> anthropocene-river-journey
# 12724 <-> anthropocene-river-school
# 12724 <-> anthropocene-working-group
# 12724 <-> anthropos
# 12724 <-> anthropos-in-the-lakes
# 12724 <-> approaching-a-waterway
# 12724 <-> arctic-change
# 12724 <-> art-air-and-ideas-in-the-anthropocene-2
# 12724 <-> asbestos-in-ambler
# 12724 <-> axiomatic-earth
# 12724 <-> bastar-diary
# 12724 <-> before-i-know-you
# 12724 <-> between-spaces-between-lines
# 12724 <-> beyond-property
# 12724 <-> biometric-capitalism
# 12724 <-> biosphere-2-the-mars-project
# 12724 <-> blackboyjoy-on-the-river-eugene-b-redmond-81
# 12724 <-> blackhawk-park-is-indigenous-land-beyond-acknowledgment
# 12724 <-> born-secret
# 12724 <-> bound-with-bright-beautiful-things
# 12724 <-> tree-x-office
# 12724 <-> twin-cities-artist-residency-mississippi-an-anthropocene-story
# 12724 <-> typha-the-once-and-future-planty-companion
# 12724 <-> uncalculated-risk
# 12724 <-> understanding-the-north-american-lost-crops
# 12724 <-> us-southwest
# 12724 <-> ve-vm-vt-the-ideal-cosmic-messengers
# 12724 <-> voice-and-representation
# 12724 <-> walk-about-it
# 12724 <-> white-sands
# ...
# 12856 <-> 1574976765849-ipgray
# 12856 <-> 1574977550008-ipgray
# 12856 <-> 1574977559823-ipgray
# 12856 <-> 1574977828885-ipgray
# 12856 <-> 1574978075613-ipgray
# 12856 <-> 1574978221296-ipgray
# 12856 <-> 1574978350796-ipgray
# 12856 <-> 1574978506628-ipgray
# 12856 <-> 1574978716778-ipgray
# 12856 <-> 1574978809451-ipgray
# 12856 <-> 1574978915266-ipgray
# 12856 <-> 1574979216434-ipgray
# 12856 <-> 1575027202459-simon-turner
# 12856 <-> 1575637610375-bsteininger
# 12856 <-> 1575637897287-bsteininger
# 12856 <-> 1575638478266-bsteininger
# 12856 <-> 1575639612739-bsteininger
# 12856 <-> 1575639851751-bsteininger
# 12856 <-> 1575640348687-bsteininger
# 12856 <-> 1575926121165-audrey
# 12856 <-> 1575927775252-audrey
# 12856 <-> 1575992123243-johnwkim
# 12856 <-> 1575992254429-johnwkim
# 12856 <-> 1579261513388-simon-turner
# 12856 <-> 1579852797747-alexanderwschindler
# 12856 <-> 1590919178472-tturnbull
# 12856 <-> 16879
# 12856 <-> 16883
# 12856 <-> 16887
# 12856 <-> 17011
# 12856 <-> 17014
# 12856 <-> 17017
# 12856 <-> 17346
# 12856 <-> 18114
# 12856 <-> 18117
# 12856 <-> 18121
# 12856 <-> 18124
# 12856 <-> 18127
# 12856 <-> 18130
# 12856 <-> 18339
# 12856 <-> 21810
# 12856 <-> 22785-2
# 12856 <-> 30-days-on-30-days-off-paul-perko
# 12856 <-> a-brief-history-of-geoengineering
# 12856 <-> a-caribbean-taste-of-technology-creolization-and-the-ways-of-making-of-the-dancehall-sound-system
# 12856 <-> a-curriculum-for-the-anthropocene
# 12856 <-> a-legacy-of-the-technosphere
# 12856 <-> a-n-t-h-r-o-p-o-z-i-n-e-0
# 12856 <-> a-recipe-for-crafting-color-the-revival-of-natural-dyeing-in-south-india
# 12856 <-> a-river-indicts
# 12856 <-> a-river-semester
# 12856 <-> a-seed-a-sound
# 12856 <-> a-slobjects-exercise-whats-in-our-pockets
# 12856 <-> a-suspended-archive
# 12856 <-> a-trace-a-breath
# 12856 <-> ac-event-2016
# 12856 <-> acknowledging-indigenous-land-and-a-performance-of-idle-no-more-bonus-episode
# 12856 <-> acquiring-and-optimizing-sustainable-relationships-for-good-solid-cash-flow-streams-or-speaking-with-plants
# 12856 <-> adaptive-modeling
# 12856 <-> after-extraction-a-partical-political-ecology-of-central-illinois
# 12856 <-> agricultural-revolution-vs-the-industrial-revolution
# 12856 <-> alternatives-to-global-challenges
# 12856 <-> ambient-infrastructures-generator-life-in-nigeria
# 12856 <-> amongst-relatives
# 12856 <-> an-anthropocene-challenge-creating-models-for-landscape-scale-change
# 12856 <-> an-anthropocene-in-two-parts
# 12856 <-> anthropocene-archeology-of-the-present
# 12856 <-> anthropocene-campus-melbourne
# 12856 <-> anthropocene-campus-melbourne-2018-a-report
# 12856 <-> anthropocene-campus-philadelphia
# 12856 <-> anthropocene-campus-venice-2021
# 12856 <-> anthropocene-east-asia
# 12856 <-> anthropocene-india
# 12856 <-> anthropocene-lecture-john-mcneill
# 12856 <-> anthropocene-lecture-julia-adeney-thomas
# 12856 <-> anthropocene-lecture-karen-litfin
# 12856 <-> anthropocene-lecture-philippe-descola
# 12856 <-> anthropocene-lecture-prasannan-parthasarathi
# 12856 <-> anthropocene-lecture-sheila-jasanoff
# 12856 <-> anthropocene-reinsurance-corporation-anthrore
# 12856 <-> anthropocene-river-campus-opening-plenary
# 12856 <-> anthropocene-river-campus-plenary-i
# 12856 <-> anthropocene-river-campus-seminar-clashing-temporalities
# 12856 <-> anthropocene-river-campus-seminar-commodity-flows
# 12856 <-> anthropocene-river-campus-seminar-exhaustion-and-imagination
# 12856 <-> anthropocene-river-campus-seminar-un-bounded-engineering-and-evolutionary-stability
# 12856 <-> anthropocene-river-campus-the-human-delta
# 12856 <-> anthropocene-river-campus-the-human-delta-short-film
# 12856 <-> anthropocene-river-journey
# 12856 <-> anthropocene-river-school
# 12856 <-> anthropocene-working-group
# 12856 <-> anthropos
# 12856 <-> anthropos-in-the-lakes
# 12856 <-> approaching-a-waterway
# 12856 <-> arctic-change
# 12856 <-> art-air-and-ideas-in-the-anthropocene-2
# 12856 <-> asbestos-in-ambler
# 12856 <-> axiomatic-earth
# 12856 <-> bastar-diary
# 12856 <-> before-i-know-you
# 12856 <-> between-spaces-between-lines
# 12856 <-> beyond-property
# 12856 <-> biometric-capitalism
# 12856 <-> biosphere-2-the-mars-project
# 12856 <-> blackboyjoy-on-the-river-eugene-b-redmond-81
# 12856 <-> blackhawk-park-is-indigenous-land-beyond-acknowledgment
# 12856 <-> born-secret
# 12856 <-> bound-with-bright-beautiful-things
# 12856 <-> broadcasting-live-from-field-station-5-the-culture-of-resistance-by-land-and-sea-in-the-anthropocene
# 12856 <-> build-your-own-fence
# 12856 <-> cadillac-ranch-2004
# 12856 <-> campus-2014
# 12856 <-> campus-2016
# 12856 <-> check-my-pulse
# 12856 <-> chinas-blue-territory-and-the-technosphere-in-maritime-east-asia
# 12856 <-> citizenship-and-technologies-of-bordering
# 12856 <-> closing-discussion-with-akeel-bilgrami-and-bernd-scherer
# 12856 <-> comics-and-graphic-novels
# 12856 <-> conference-state-of-nature-in-india
# 12856 <-> confluence-bus-tour-reflection
# 12856 <-> confluence-ecologies
# 12856 <-> contesting-the-de-industrial-futures-of-the-upper-mississippi
# 12856 <-> continent-inter-view-arno-rosemarin-on-disconcerting-technical-systems
# 12856 <-> continent-inter-view-bronislaw-szerszynski-on-the-technosphere
# 12856 <-> contra-diction-speech-against-itself
# 12856 <-> conundrums-on-country
# 12856 <-> conversations
# 12856 <-> coordinating-practice
# 12856 <-> creolized-technologies-of-demoralization
# 12856 <-> damming-of-the-narmada-river-in-india
# 12856 <-> dancing-the-technosphere
# 12856 <-> data-flow
# 12856 <-> data-sensing
# 12856 <-> deconstructing-fences
# 12856 <-> deconstructing-the-we
# 12856 <-> deep-time-chicago
# 12856 <-> deep-time-chicago-lecture
# 12856 <-> deep-time-walking
# 12856 <-> defining-the-anthropocene
# 12856 <-> deserts-the-geopolitics-of-geology
# 12856 <-> dramatizing-the-future
# 12856 <-> drawn-together
# 12856 <-> driving-the-golden-spike
# 12856 <-> driving-the-limits-of-time
# 12856 <-> eating-the-anthropocene
# 12856 <-> economic-framing-environmental-governance-and-teaching-pluralist-economics
# 12856 <-> edible-encounters-along-the-mississippi-river
# 12856 <-> enter-anthropocene-searching-for-signal-in-new-orleans
# 12856 <-> environing-technology
# 12856 <-> environmental-geochemistry-of-river-sediments
# 12856 <-> essay-series
# 12856 <-> exhibition-opening-at-g-cadd-st-louis
# 12856 <-> extracts-and-exclusions
# 12856 <-> feeling-following-creative-experiments-and-material-play
# 12856 <-> field-station-1-sediment-settlement-sentiment
# 12856 <-> field-station-2-anthropocene-drift
# 12856 <-> field-station-3-anthropocene-vernacular
# 12856 <-> field-station-4-confluence-ecologies
# 12856 <-> field-station-5-commodity-exploitation
# 12856 <-> field-stations
# 12856 <-> field-trips
# 12856 <-> film-residency-mississippi-an-anthropocene-river
# 12856 <-> financialization-as-a-parody
# 12856 <-> forecasting-earth-futures
# 12856 <-> fort-snellings-deep-time-stories
# 12856 <-> freshkills-new-york-city
# 12856 <-> from-a-living-exhibition-to-the-dmz
# 12856 <-> from-limits-to-growth-to-chernobyl
# 12856 <-> from-plantations-to-petrochemicals
# 12856 <-> from-valuing-nature-to-reclaiming-resources
# 12856 <-> from-valuing-nature-to-reclaiming-resources-2
# 12856 <-> gas-flares-in-the-bakken-oil-fields-williston-north-dakota-2013
# 12856 <-> geo-politics
# 12856 <-> global-systems-simulator-gss
# 12856 <-> going-against-the-flow
# 12856 <-> grinders
# 12856 <-> histories-of-disintegration
# 12856 <-> hopium-economy
# 12856 <-> how-does-the-world-end-for-others
# 12856 <-> how-not-what-power-time-landscape
# 12856 <-> humanities-on-the-ground
# 12856 <-> hurricane-katrina
# 12856 <-> images-of-the-anthropocene
# 12856 <-> imagination-of-the-terra
# 12856 <-> imagine-the-anthropocene-with-a-little-help-from-the-monster-in-you
# 12856 <-> imagining-an-economy-based-on-care
# 12856 <-> infrastructures
# 12856 <-> infrastrucural-nature
# 12856 <-> inheritance
# 12856 <-> inside-the-museum
# 12856 <-> interspecies-accomplices-cultivating-conspiracy-at-the-royal-botanic-gardens-victoria
# 12856 <-> introduction-3
# 12856 <-> introductions-to-matters-2
# 12856 <-> ioway
# 12856 <-> is-the-anthropocene-a-doomsday-device-2
# 12856 <-> islands-colonialism-and-geopolitics
# 12856 <-> jakarta-a-colonial-water-management-fantasy-park
# 12856 <-> kairos-earthquake-early-warning-application
# 12856 <-> kansan-view-from-iowa-point-1-glacial
# 12856 <-> kick-off-anthropocene-river-journey
# 12856 <-> kish-an-island-indecisive-by-design
# 12856 <-> knowing-in-the-anthropocene
# 12856 <-> knowing-together
# 12856 <-> la-arboleda
# 12856 <-> laboratory-for-a-radical-suburbia
# 12856 <-> lake-chad-narratives
# 12856 <-> lake-chad-sharing-a-diminishing-resource
# 12856 <-> land-acknowledgement-statement
# 12856 <-> layers-of-violence
# 12856 <-> limits-to-growth
# 12856 <-> lisboa-parallax-2020
# 12856 <-> listening-to-the-mississippi
# 12856 <-> living-arctic-infrastructures-2
# 12856 <-> looking-downstream
# 12856 <-> lost-voices
# 12856 <-> louisiana-a-planetary-reactor
# 12856 <-> lounging-through-the-flood
# 12856 <-> mapping-an-exercise-in-cartography
# 12856 <-> measuring-loss
# 12856 <-> meeker-dam
# 12856 <-> memories-of-the-yagan-the-chilean-automobile-for-the-people
# 12856 <-> meskonsing-indian-lake-convergence-1
# 12856 <-> meskonsing-kansan
# 12856 <-> meskonsing-kansan-an-introduction
# 12856 <-> midway-meeting-st-louis
# 12856 <-> mikado-sol-2014
# 12856 <-> mississippi
# 12856 <-> mobile-hedges
# 12856 <-> monsanto-town
# 12856 <-> museum-library
# 12856 <-> natchez-etiologies-of-athropogenic-emergence
# 12856 <-> navigating-the-anthropocene-river
# 12856 <-> new-orleans-anthropocene-field-campus
# 12856 <-> nigeria-oil-pipes
# 12856 <-> nordic-fauna-seen-in-nature
# 12856 <-> ny-alesund-svalbard-norway
# 12856 <-> of-forests-of-rivers-and-of-meals
# 12856 <-> on-anthropotechnics-and-physical-practice
# 12856 <-> on-consuming-slow-media
# 12856 <-> on-land-and-lakes-colonizing-the-north
# 12856 <-> on-the-operation-of-border-regimes
# 12856 <-> on-the-recuperative-mismanagement-of-a-cosmopolitan-fish
# 12856 <-> on-the-use-of-the-word-code-by-the-kogi-translator
# 12856 <-> one-place-many-names
# 12856 <-> one-world-solid-and-cracked
# 12856 <-> open-seminars
# 12856 <-> orbital-geopolitics
# 12856 <-> outrunning-the-anthropocene
# 12856 <-> over-the-levee-under-the-plow
# 12856 <-> oysters-selective-pressures-and-antibiotic-resistance-in-the-mississippi-delta
# 12856 <-> paddle-waves-and-sparkling-light
# 12856 <-> panel-talk-beween-patricia-piccinini-and-claudia-vickers
# 12856 <-> parallax-lisboa
# 12856 <-> patagonia
# 12856 <-> performing-the-anthropocene
# 12856 <-> peter-schlemihl-exploring-anthropocenic-landscapes
# 12856 <-> pharmocracy-access-and-care
# 12856 <-> phenomenal-machines-2
# 12856 <-> place-and-space
# 12856 <-> plant-domestication-and-dispersal
# 12856 <-> planting-a-seed-is-revolutionary-act
# 12856 <-> plastic-and-surrogacy
# 12856 <-> pockets-reflections-on-the-anthropocene-campus-melbourne
# 12856 <-> praying-for-the-water-with-saundi-mcclain-kloeckner
# 12856 <-> producing-the-anthropocene-producing-the-future
# 12856 <-> project-launch-minneapolis
# 12856 <-> prologue-the-fence-concept
# 12856 <-> re-patterning-with-kudzu
# 12856 <-> real-estate-river
# 12856 <-> redeeming-urban-spaces-the-ambivalence-of-building-a-pentecostal-city-in-lagos-nigeria
# 12856 <-> remnant-formations
# 12856 <-> reshaping-the-shape-embodiment-ecology-and-culture-of-a-postnatural-carp
# 12856 <-> resisting-the-oblivion-of-eco-colonialism
# 12856 <-> resonance-vegetale
# 12856 <-> risk-as-immaterial-raw-material
# 12856 <-> risk-equity-in-the-louisiana-anthropocene
# 12856 <-> river-memory
# 12856 <-> river-semester
# 12856 <-> river-semester-project
# 12856 <-> rogue-elements-of-the-upper-mississippi
# 12856 <-> sacrifice-zones-and-portable-climate
# 12856 <-> seminar-algorithmic-intermediation-and-smartness
# 12856 <-> seminar-anthropogenic-landscapes
# 12856 <-> seminar-archiving
# 12856 <-> seminar-claims-property
# 12856 <-> seminar-clashing-temporalities
# 12856 <-> seminar-co-evolution-of-the-technosphere
# 12856 <-> seminar-co-evolutionary-perspectives
# 12856 <-> seminar-commodity-flows
# 12856 <-> seminar-communicating
# 12856 <-> seminar-consensus-building
# 12856 <-> seminar-disciplinarities
# 12856 <-> seminar-exhaustion-and-imagination
# 12856 <-> seminar-film-clashing-temporalities
# 12856 <-> seminar-film-commodity-flows
# 12856 <-> seminar-film-exhaustion-and-imagination
# 12856 <-> seminar-film-un-bounded-engineering-and-evolutionary-stability
# 12856 <-> seminar-filtering-the-anthropocene
# 12856 <-> seminar-governing-the-technosphere
# 12856 <-> seminar-imaging-the-anthropocene
# 12856 <-> seminar-modelling-wicked-problems
# 12856 <-> seminar-reflection-2
# 12856 <-> seminar-reflections-algorithmic-intermediation-and-smartness
# 12856 <-> seminar-report-anthropogenic-landscapes
# 12856 <-> seminar-report-filtering-the-anthropocene
# 12856 <-> seminar-report-geo-politics
# 12856 <-> seminar-report-slow-media
# 12856 <-> seminar-risk-equity
# 12856 <-> seminar-romancing-the-anthropocene
# 12856 <-> seminar-sensing
# 12856 <-> seminar-sensing-the-insensible
# 12856 <-> seminar-slow-media
# 12856 <-> seminar-techno-metabolism
# 12856 <-> seminar-un-bounded-engineering-and-evolutionary-stability
# 12856 <-> seminar-valuing-nature
# 12856 <-> sever-pre-emptive-strategy-for-an-open-arctic
# 12856 <-> shadowing-the-anthropocene
# 12856 <-> shaped-by-rivers
# 12856 <-> sharing-surveillance-data
# 12856 <-> significant-and-insignificant-mounds
# 12856 <-> significant-and-insignificant-mounds-2
# 12856 <-> slow-disaster
# 12856 <-> social-witnessing
# 12856 <-> somewhere-somehow-a-co-evolution-story
# 12856 <-> sounding-landscapes
# 12856 <-> specifics-of-vulnerability
# 12856 <-> st-louis-anthropocene-field-campus
# 12856 <-> state-of-nature-in-india
# 12856 <-> state-of-nature-some-philosophical-issues
# 12856 <-> stranging-the-anthropocene-refraction
# 12856 <-> systems-analysis-and-modeling
# 12856 <-> t-rain-lines
# 12856 <-> tactics-for-quotidian-anthropocenes
# 12856 <-> tactics-for-quotidian-anthropocenes-2
# 12856 <-> taking-nature-into-account-historical-perspectives-and-paradoxes
# 12856 <-> technosphere-co-evolution-a-seminal-seminar-conversation
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-5380571b4c39> in <module>
#      26         unprocessed_contents = dict([(key, val) for key, val in contents.items() if key not in processed_article_ids])
#      27
# ---> 28         similarities = anthropocene_analyzer.get_article_similarities(article_id, unprocessed_contents)
#      29         sorted_similarities = dict(sorted(similarities.items(), key=lambda item: item[1], reverse=True))
#      30
#
# ~/Dropbox/VIDAN/Nebenprojekte/DMACP/code/dmacp/jonas/lib/anthropocene/Analyzer.py in get_article_similarities(self, article_id, article_contents)
#      20             print(article_id, '<->', compare_id)
#      21
# ---> 22             doc2 = self.nlp(compare_text)
#      23             similarities[compare_id] = doc1.similarity(doc2)
#      24         return similarities
#
# /usr/local/lib/python3.9/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     987                 error_handler = proc.get_error_handler()
#     988             try:
# --> 989                 doc = proc(doc, **component_cfg.get(name, {}))
#     990             except KeyError as e:
#     991                 # This typically happens if a component is not initialized
#
# /usr/local/lib/python3.9/site-packages/spacy/pipeline/trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# /usr/local/lib/python3.9/site-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.set_annotations()
#
# /usr/local/lib/python3.9/site-packages/spacy/pipeline/_parser_internals/ner.pyx in spacy.pipeline._parser_internals.ner.BiluoPushDown.set_annotations()
#
# /usr/local/lib/python3.9/site-packages/spacy/tokens/doc.pyx in spacy.tokens.doc.Doc.set_ents()
#
# /usr/local/lib/python3.9/site-packages/spacy/tokens/doc.pyx in spacy.tokens.doc.SetEntsDefault.values()
#
# /usr/local/Cellar/python@3.9/3.9.2/Frameworks/Python.framework/Versions/3.9/lib/python3.9/enum.py in __members__(cls)
#     417         return len(cls._member_names_)
#     418
# --> 419     @property
#     420     def __members__(cls):
#     421         """
#
# KeyboardInterrupt:

# %% [markdown]
# Create similarity file for each article by taking the (imcomplete) similarity file and adding the missing similarities from the counterpart files:

# %%
import json
import numpy
import os

# ---

source_dir = './data/analysis/article_similarities/raw'
article_contents_filepath = './data/preprocess/merged/fully_merged_contents.json'
output_dir = './data/analysis/article_similarities'

# ---

def get_similarity_from_file(filepath, article_id):
    with open(filepath) as file:
        data = json.load(file)
    return data[article_id]

# ---

# Delete previously created files
filelist = [ f for f in os.listdir(output_dir) if f.endswith(".json") ]
for f in filelist:
    os.remove(os.path.join(output_dir, f))

# ---

# Load article contents to get ids
with open(article_contents_filepath) as article_contents_file:
    article_contents = json.load(article_contents_file)
    complete_article_ids = list(article_contents.keys())

# Iterate through files and add missing data
for article_id in complete_article_ids:
    similarity_file_path = '%s/%s.json' % (source_dir, article_id)
    if not os.path.exists(similarity_file_path):
        continue

    # Open similarity file to add data
    with open(similarity_file_path) as similarity_file:
        raw_similarities = json.load(similarity_file)

        existing_similarities = list(raw_similarities.keys())
        missing_article_ids = numpy.setdiff1d(complete_article_ids, existing_similarities)

        for missing_article_id in missing_article_ids:
            if missing_article_id == article_id:
                continue

            missing_article_filepath = '%s/%s.json' % (source_dir, missing_article_id)
            raw_similarities[missing_article_id] = get_similarity_from_file(missing_article_filepath, article_id)

        # Sort data and write to json file
        sorted_similarities = dict(sorted(raw_similarities.items(), key=lambda item: item[1], reverse=True))
        outfile_path = '%s/%s.json' % (output_dir, article_id)
        with open(outfile_path, 'w') as outfile:
            json.dump(sorted_similarities, outfile, sort_keys=False, indent=4)
